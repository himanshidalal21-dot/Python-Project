# %% [markdown]
# <a href="https://colab.research.google.com/github/himanshidalal21-dot/Python-Project/blob/main/PythonProject.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Password Generate Python Project Module

import random

alpha = "abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ"
number = "0123456789"
special = "!@#$%^&*()_+-=[]{}|;:,.<>/?"

print("***Welcome to the Password Generator***")

length = int(input("Enter the desired length of your password: "))
password = ""

# combine all characters
all_char = alpha + number + special

for i in range(length):
  password += random.choice(all_char)

print("Your generated password is: ",password)
# Out:
# ***Welcome to the Password Generator***
# Enter the desired length of your password: 6
# Your generated password is:  &<cY@|
